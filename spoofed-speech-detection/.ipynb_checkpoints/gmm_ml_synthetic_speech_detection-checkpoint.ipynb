# %% [markdown]
# # Spoofed Speech Detection via Maximum Likelihood Estimation of Gaussian Mixture Models
# The goal of synthetic speech detection is to determine whether a speech segment $S$ is natural or synthetic/converted speeach.
#
# This notebook implements a Gaussian mixture model maximum likelihood (GMM-ML) classifier for synthetic (spoofed) speech detection. This approach uses regular mel frequency cepstral coefficients (MFCC) features and gives the best performance on the [ASVspoof 2015 dataset](https://www.idiap.ch/dataset/avspoof) among the standard classifiers (GMM-SV, GMM-UBM, ...). For more background information see: *Hanilçi, Cemal, Tomi Kinnunen, Md Sahidullah, and Aleksandr Sizov. "Classifiers for synthetic speech detection: a comparison." In INTERSPEECH 2015*. The scripts use the Python package [Bob.Bio.SPEAR 2.04](https://pypi.python.org/pypi/bob.bio.spear/2.0.4) for speaker recogntion.
#
# This work is part of the ["DDoS Resilient Emergency Dispatch Center"](https://www.dhs.gov/science-and-technology/news/2015/09/04/dhs-st-awards-university-houston-26m-cyber-security-research) project at the University of Houston, funded by the Department of Homeland Security (DHS).
#
#
# April 19, 2015
#
# Lorenzo Rossi
#
# (lorenzo **[dot]** rossi **[at]** gmail **[dot]** com)

# %%
import os
import time
import numpy as np
import pandas as pd
import scipy
from bob.bio.spear import preprocessor, extractor
from bob.bio.gmm import algorithm
from bob.io.base import HDF5File
from bob.learn import em
from sklearn.metrics import classification_report, roc_curve, roc_auc_score


def read(filename):
  """Read video.FrameContainer containing preprocessed frames"""

  fileName, fileExtension = os.path.splitext(filename)
  wav_filename = filename
  rate, data = scipy.io.wavfile.read(str(wav_filename)) # the data is read in its native format
  if data.dtype =='int16':
    data = np.cast['float'](data)
  return [rate,data]


WAV_FOLDER = '/data/chendan/wav/' #'ASV2015dataset/wav/' # Path to folder containing speakers .wav subfolders
LABEL_FOLDER = '/data/chendan/protocal/CM_protocol/' #'ASV2015dataset/CM_protocol/' # Path to ground truth csv files

EXT = '.wav'
# %matplotlib inline

# %% [markdown]
# ## Loading the Ground Truth
# Load the dataframes (tables) with the labels for the training, development and evaluation (hold out) sets. Each subfolder corresponds to a different speaker. For example, T1 and D4 indicate the subfolders associated to the utterances and spoofed segments of speakers T1 and D4, respectively in training and development sets. Note that number of evaluation samples >> number of development samples >> testing samples.
#
# You can either select the speakers in each set one by one, *e.g.*:
# ```
# train_subfls = ['T1', 'T2']
# ```
# will only load segments from speakers T1 and T2 for training,
#
# or use all the available speakers in a certain subset by leaving the list empty, *e.g.*:
# ```
# devel_subfls = []
# ```
# will load all the available Dx speaker segments for the development stage. If you are running this notebook for the first time, you may want to start only with 2 or so speakers per set for sake of quick testing. All the scripts may take several hours to run on the full size datsets.

# %%
train_subfls = ['T1','T3']#, 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T13']  #T13 used instead of T10 for gender balance
devel_subfls = ['D1','D3']#, 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9', 'D10']
evalu_subfls = ['E1']#, 'E2', 'E3', 'E4', 'E5', 'E6','E7',  'E8', 'E9', 'E10']
train = pd.read_csv(LABEL_FOLDER + 'cm_train.trn', sep=' ', header=None, names=['folder','file','method','source'])
if len(train_subfls): train = train[train.folder.isin(train_subfls)]
train.sort_values(['folder', 'file'], inplace=True)
# print(train)
devel = pd.read_csv(LABEL_FOLDER + 'cm_develop.ndx', sep=' ', header=None, names=['folder','file','method','source'])
if len(devel_subfls): devel = devel[devel.folder.isin(devel_subfls)]
devel.sort_values(['folder', 'file'], inplace=True)
print(devel)
evalu = pd.read_csv(LABEL_FOLDER +'cm_evaluation_0103.ndx', sep=' ', header=None, names=['folder','file','method','source'])
if len(evalu_subfls): evalu = evalu[evalu.folder.isin(evalu_subfls)]

evalu.sort_values(['folder', 'file'], inplace=True)

label_2_class = {'human':1, 'spoof':0}

print('training samples:',len(train))
print('development samples:',len(devel))
print('evaluation samples:',len(evalu))
# Out:
#      folder        file method source
# 2597     D1  D1_1002598  human  human
# 2598     D1  D1_1002599  human  human
# 2599     D1  D1_1002600  human  human
# 2600     D1  D1_1002601  human  human
# 2601     D1  D1_1002602  human  human
# ...     ...         ...    ...    ...
# 7767     D3  D3_1007768     S1  spoof
# 7768     D3  D3_1007769     S2  spoof
# 7769     D3  D3_1007770     S3  spoof
# 7770     D3  D3_1007771     S4  spoof
# 7771     D3  D3_1007772     S5  spoof
#
# [3050 rows x 4 columns]
# training samples: 1310
# development samples: 3050
# evaluation samples: 20

# %% [markdown]
# ## Speech Preprocessing and MFCC Extraction
# Silence removal and MFCC feature extraction for training segments. More details about the bob.bio.spear involved libraries at:
# https://www.idiap.ch/software/bob/docs/latest/bioidiap/bob.bio.spear/master/implemented.html
#
# You can also skip this stage and load a set of feaures (see **Loading features** cell).

# %%
# Parameters
n_ceps = 60 # number of ceptral coefficients (implicit in extractor)
silence_removal_ratio = .1

# %%
subfolders = train_subfls
ground_truth = train

# initialize feature matrix
features = []
y = np.zeros((len(ground_truth),))
print("Extracting features for training stage.")

vad = preprocessor.Energy_Thr(ratio_threshold=silence_removal_ratio)
cepstrum = extractor.Cepstral()

k = 0
start_time = time.clock()

n_subfls = len(subfolders)
for folder in subfolders[0:n_subfls]:
    print(folder, end=", ")
    folder = "".join((WAV_FOLDER,folder,'/'))
    # print(folder)
    f_list = os.listdir(folder)
    # print(f_list)
    for f_name in f_list:
        # ground truth
        try: 
            # 根据train中file(路径)字段，提取相应.wav文件的source(spoof or human)字段
            label = ground_truth[ground_truth.file==f_name[:-len(EXT)]].source.values[0]
        except IndexError:
            continue
        y[k] = label_2_class[label]
        # silence removal
        # print(f_name)
        # print(vad)
        x = read(folder+f_name)
        vad_data = vad(x)

        if vad_data:
            if not vad_data[2].max():
                vad = preprocessor.Energy_Thr(ratio_threshold=silence_removal_ratio*.8)
                vad_data = vad(x)
                vad = preprocessor.Energy_Thr(ratio_threshold=silence_removal_ratio)
            # MFCC extraction 
            mfcc = cepstrum(vad_data)
            features.append(mfcc)
            k += 1
        else :
            features.append(None)

Xf = np.array(features)
print(k,"files processed in",(time.clock()-start_time)/60,"minutes.")
# Out:
# Extracting features for training stage.
# T1, bob.bio.spear@2020-01-03 13:09:30,422 -- INFO: After thresholded Energy-based VAD there are 209 frames remaining over 407
# bob.bio.spear@2020-01-03 13:09:30,528 -- INFO: After thresholded Energy-based VAD there are 143 frames remaining over 273
# bob.bio.spear@2020-01-03 13:09:30,601 -- INFO: After thresholded Energy-based VAD there are 140 frames remaining over 460
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   del sys.path[0]
# bob.bio.spear@2020-01-03 13:09:30,676 -- INFO: After thresholded Energy-based VAD there are 194 frames remaining over 351
# bob.bio.spear@2020-01-03 13:09:30,774 -- INFO: After thresholded Energy-based VAD there are 116 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:30,835 -- INFO: After thresholded Energy-based VAD there are 176 frames remaining over 411
# bob.bio.spear@2020-01-03 13:09:30,925 -- INFO: After thresholded Energy-based VAD there are 93 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:30,974 -- INFO: After thresholded Energy-based VAD there are 117 frames remaining over 249
# bob.bio.spear@2020-01-03 13:09:31,034 -- INFO: After thresholded Energy-based VAD there are 140 frames remaining over 231
# bob.bio.spear@2020-01-03 13:09:31,104 -- INFO: After thresholded Energy-based VAD there are 126 frames remaining over 287
# bob.bio.spear@2020-01-03 13:09:31,169 -- INFO: After thresholded Energy-based VAD there are 183 frames remaining over 407
# bob.bio.spear@2020-01-03 13:09:31,261 -- INFO: After thresholded Energy-based VAD there are 56 frames remaining over 172
# bob.bio.spear@2020-01-03 13:09:31,293 -- INFO: After thresholded Energy-based VAD there are 152 frames remaining over 377
# bob.bio.spear@2020-01-03 13:09:31,371 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 293
# bob.bio.spear@2020-01-03 13:09:31,419 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 377
# bob.bio.spear@2020-01-03 13:09:31,509 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:31,553 -- INFO: After thresholded Energy-based VAD there are 189 frames remaining over 334
# bob.bio.spear@2020-01-03 13:09:31,647 -- INFO: After thresholded Energy-based VAD there are 141 frames remaining over 283
# bob.bio.spear@2020-01-03 13:09:31,719 -- INFO: After thresholded Energy-based VAD there are 66 frames remaining over 242
# bob.bio.spear@2020-01-03 13:09:31,756 -- INFO: After thresholded Energy-based VAD there are 209 frames remaining over 454
# bob.bio.spear@2020-01-03 13:09:31,862 -- INFO: After thresholded Energy-based VAD there are 84 frames remaining over 404
# bob.bio.spear@2020-01-03 13:09:31,909 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 289
# bob.bio.spear@2020-01-03 13:09:31,967 -- INFO: After thresholded Energy-based VAD there are 82 frames remaining over 185
# bob.bio.spear@2020-01-03 13:09:32,011 -- INFO: After thresholded Energy-based VAD there are 84 frames remaining over 185
# bob.bio.spear@2020-01-03 13:09:32,055 -- INFO: After thresholded Energy-based VAD there are 49 frames remaining over 193
# bob.bio.spear@2020-01-03 13:09:32,084 -- INFO: After thresholded Energy-based VAD there are 187 frames remaining over 549
# bob.bio.spear@2020-01-03 13:09:32,182 -- INFO: After thresholded Energy-based VAD there are 158 frames remaining over 268
# bob.bio.spear@2020-01-03 13:09:32,261 -- INFO: After thresholded Energy-based VAD there are 115 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:32,321 -- INFO: After thresholded Energy-based VAD there are 115 frames remaining over 244
# bob.bio.spear@2020-01-03 13:09:32,381 -- INFO: After thresholded Energy-based VAD there are 200 frames remaining over 524
# bob.bio.spear@2020-01-03 13:09:32,483 -- INFO: After thresholded Energy-based VAD there are 69 frames remaining over 224
# bob.bio.spear@2020-01-03 13:09:32,521 -- INFO: After thresholded Energy-based VAD there are 60 frames remaining over 172
# bob.bio.spear@2020-01-03 13:09:32,553 -- INFO: After thresholded Energy-based VAD there are 68 frames remaining over 154
# bob.bio.spear@2020-01-03 13:09:32,590 -- INFO: After thresholded Energy-based VAD there are 89 frames remaining over 280
# bob.bio.spear@2020-01-03 13:09:32,638 -- INFO: After thresholded Energy-based VAD there are 91 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:32,685 -- INFO: After thresholded Energy-based VAD there are 97 frames remaining over 167
# bob.bio.spear@2020-01-03 13:09:32,735 -- INFO: After thresholded Energy-based VAD there are 126 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:32,799 -- INFO: After thresholded Energy-based VAD there are 110 frames remaining over 253
# bob.bio.spear@2020-01-03 13:09:32,857 -- INFO: After thresholded Energy-based VAD there are 129 frames remaining over 413
# bob.bio.spear@2020-01-03 13:09:32,926 -- INFO: After thresholded Energy-based VAD there are 148 frames remaining over 348
# bob.bio.spear@2020-01-03 13:09:33,001 -- INFO: After thresholded Energy-based VAD there are 112 frames remaining over 253
# bob.bio.spear@2020-01-03 13:09:33,060 -- INFO: After thresholded Energy-based VAD there are 184 frames remaining over 428
# bob.bio.spear@2020-01-03 13:09:33,153 -- INFO: After thresholded Energy-based VAD there are 66 frames remaining over 207
# bob.bio.spear@2020-01-03 13:09:33,190 -- INFO: After thresholded Energy-based VAD there are 241 frames remaining over 344
# bob.bio.spear@2020-01-03 13:09:33,308 -- INFO: After thresholded Energy-based VAD there are 122 frames remaining over 251
# bob.bio.spear@2020-01-03 13:09:33,372 -- INFO: After thresholded Energy-based VAD there are 137 frames remaining over 391
# bob.bio.spear@2020-01-03 13:09:33,444 -- INFO: After thresholded Energy-based VAD there are 183 frames remaining over 428
# bob.bio.spear@2020-01-03 13:09:33,538 -- INFO: After thresholded Energy-based VAD there are 155 frames remaining over 575
# bob.bio.spear@2020-01-03 13:09:33,620 -- INFO: After thresholded Energy-based VAD there are 75 frames remaining over 276
# bob.bio.spear@2020-01-03 13:09:33,663 -- INFO: After thresholded Energy-based VAD there are 188 frames remaining over 531
# bob.bio.spear@2020-01-03 13:09:33,760 -- INFO: After thresholded Energy-based VAD there are 101 frames remaining over 336
# bob.bio.spear@2020-01-03 13:09:33,815 -- INFO: After thresholded Energy-based VAD there are 157 frames remaining over 455
# bob.bio.spear@2020-01-03 13:09:33,896 -- INFO: After thresholded Energy-based VAD there are 107 frames remaining over 265
# bob.bio.spear@2020-01-03 13:09:33,953 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 407
# bob.bio.spear@2020-01-03 13:09:34,044 -- INFO: After thresholded Energy-based VAD there are 52 frames remaining over 141
# bob.bio.spear@2020-01-03 13:09:34,074 -- INFO: After thresholded Energy-based VAD there are 250 frames remaining over 454
# bob.bio.spear@2020-01-03 13:09:34,198 -- INFO: After thresholded Energy-based VAD there are 102 frames remaining over 224
# bob.bio.spear@2020-01-03 13:09:34,252 -- INFO: After thresholded Energy-based VAD there are 245 frames remaining over 383
# bob.bio.spear@2020-01-03 13:09:34,375 -- INFO: After thresholded Energy-based VAD there are 154 frames remaining over 357
# bob.bio.spear@2020-01-03 13:09:34,453 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 207
# bob.bio.spear@2020-01-03 13:09:34,489 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:34,534 -- INFO: After thresholded Energy-based VAD there are 52 frames remaining over 219
# bob.bio.spear@2020-01-03 13:09:34,566 -- INFO: After thresholded Energy-based VAD there are 194 frames remaining over 536
# bob.bio.spear@2020-01-03 13:09:34,666 -- INFO: After thresholded Energy-based VAD there are 149 frames remaining over 275
# bob.bio.spear@2020-01-03 13:09:34,741 -- INFO: After thresholded Energy-based VAD there are 123 frames remaining over 262
# bob.bio.spear@2020-01-03 13:09:34,805 -- INFO: After thresholded Energy-based VAD there are 207 frames remaining over 390
# bob.bio.spear@2020-01-03 13:09:34,907 -- INFO: After thresholded Energy-based VAD there are 98 frames remaining over 345
# bob.bio.spear@2020-01-03 13:09:34,960 -- INFO: After thresholded Energy-based VAD there are 52 frames remaining over 194
# bob.bio.spear@2020-01-03 13:09:34,990 -- INFO: After thresholded Energy-based VAD there are 90 frames remaining over 391
# bob.bio.spear@2020-01-03 13:09:35,041 -- INFO: After thresholded Energy-based VAD there are 296 frames remaining over 505
# bob.bio.spear@2020-01-03 13:09:35,187 -- INFO: After thresholded Energy-based VAD there are 180 frames remaining over 407
# bob.bio.spear@2020-01-03 13:09:35,280 -- INFO: After thresholded Energy-based VAD there are 173 frames remaining over 485
# bob.bio.spear@2020-01-03 13:09:35,370 -- INFO: After thresholded Energy-based VAD there are 244 frames remaining over 454
# bob.bio.spear@2020-01-03 13:09:35,492 -- INFO: After thresholded Energy-based VAD there are 145 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:35,566 -- INFO: After thresholded Energy-based VAD there are 119 frames remaining over 315
# bob.bio.spear@2020-01-03 13:09:35,628 -- INFO: After thresholded Energy-based VAD there are 108 frames remaining over 219
# bob.bio.spear@2020-01-03 13:09:35,683 -- INFO: After thresholded Energy-based VAD there are 93 frames remaining over 332
# bob.bio.spear@2020-01-03 13:09:35,733 -- INFO: After thresholded Energy-based VAD there are 112 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:35,792 -- INFO: After thresholded Energy-based VAD there are 208 frames remaining over 402
# bob.bio.spear@2020-01-03 13:09:35,897 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 283
# bob.bio.spear@2020-01-03 13:09:35,956 -- INFO: After thresholded Energy-based VAD there are 120 frames remaining over 253
# bob.bio.spear@2020-01-03 13:09:36,017 -- INFO: After thresholded Energy-based VAD there are 139 frames remaining over 356
# bob.bio.spear@2020-01-03 13:09:36,091 -- INFO: After thresholded Energy-based VAD there are 290 frames remaining over 458
# bob.bio.spear@2020-01-03 13:09:36,232 -- INFO: After thresholded Energy-based VAD there are 235 frames remaining over 390
# bob.bio.spear@2020-01-03 13:09:36,349 -- INFO: After thresholded Energy-based VAD there are 216 frames remaining over 424
# bob.bio.spear@2020-01-03 13:09:36,458 -- INFO: After thresholded Energy-based VAD there are 112 frames remaining over 200
# bob.bio.spear@2020-01-03 13:09:36,515 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 194
# bob.bio.spear@2020-01-03 13:09:36,557 -- INFO: After thresholded Energy-based VAD there are 104 frames remaining over 311
# bob.bio.spear@2020-01-03 13:09:36,614 -- INFO: After thresholded Energy-based VAD there are 241 frames remaining over 432
# bob.bio.spear@2020-01-03 13:09:36,733 -- INFO: After thresholded Energy-based VAD there are 70 frames remaining over 284
# bob.bio.spear@2020-01-03 13:09:36,773 -- INFO: After thresholded Energy-based VAD there are 114 frames remaining over 287
# bob.bio.spear@2020-01-03 13:09:36,834 -- INFO: After thresholded Energy-based VAD there are 187 frames remaining over 445
# bob.bio.spear@2020-01-03 13:09:36,928 -- INFO: After thresholded Energy-based VAD there are 97 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:36,978 -- INFO: After thresholded Energy-based VAD there are 74 frames remaining over 175
# bob.bio.spear@2020-01-03 13:09:37,019 -- INFO: After thresholded Energy-based VAD there are 179 frames remaining over 409
# bob.bio.spear@2020-01-03 13:09:37,109 -- INFO: After thresholded Energy-based VAD there are 72 frames remaining over 223
# bob.bio.spear@2020-01-03 13:09:37,149 -- INFO: After thresholded Energy-based VAD there are 194 frames remaining over 349
# bob.bio.spear@2020-01-03 13:09:37,246 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 223
# bob.bio.spear@2020-01-03 13:09:37,288 -- INFO: After thresholded Energy-based VAD there are 84 frames remaining over 219
# bob.bio.spear@2020-01-03 13:09:37,336 -- INFO: After thresholded Energy-based VAD there are 217 frames remaining over 681
# bob.bio.spear@2020-01-03 13:09:37,448 -- INFO: After thresholded Energy-based VAD there are 223 frames remaining over 412
# bob.bio.spear@2020-01-03 13:09:37,559 -- INFO: After thresholded Energy-based VAD there are 230 frames remaining over 501
# bob.bio.spear@2020-01-03 13:09:37,674 -- INFO: After thresholded Energy-based VAD there are 162 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:37,755 -- INFO: After thresholded Energy-based VAD there are 67 frames remaining over 281
# bob.bio.spear@2020-01-03 13:09:37,794 -- INFO: After thresholded Energy-based VAD there are 200 frames remaining over 592
# bob.bio.spear@2020-01-03 13:09:37,897 -- INFO: After thresholded Energy-based VAD there are 80 frames remaining over 241
# bob.bio.spear@2020-01-03 13:09:37,941 -- INFO: After thresholded Energy-based VAD there are 248 frames remaining over 501
# bob.bio.spear@2020-01-03 13:09:38,064 -- INFO: After thresholded Energy-based VAD there are 73 frames remaining over 176
# bob.bio.spear@2020-01-03 13:09:38,103 -- INFO: After thresholded Energy-based VAD there are 87 frames remaining over 194
# bob.bio.spear@2020-01-03 13:09:38,148 -- INFO: After thresholded Energy-based VAD there are 99 frames remaining over 249
# bob.bio.spear@2020-01-03 13:09:38,202 -- INFO: After thresholded Energy-based VAD there are 213 frames remaining over 519
# bob.bio.spear@2020-01-03 13:09:38,311 -- INFO: After thresholded Energy-based VAD there are 82 frames remaining over 306
# bob.bio.spear@2020-01-03 13:09:38,357 -- INFO: After thresholded Energy-based VAD there are 206 frames remaining over 494
# bob.bio.spear@2020-01-03 13:09:38,463 -- INFO: After thresholded Energy-based VAD there are 290 frames remaining over 492
# bob.bio.spear@2020-01-03 13:09:38,606 -- INFO: After thresholded Energy-based VAD there are 195 frames remaining over 387
# bob.bio.spear@2020-01-03 13:09:38,704 -- INFO: After thresholded Energy-based VAD there are 164 frames remaining over 394
# bob.bio.spear@2020-01-03 13:09:38,788 -- INFO: After thresholded Energy-based VAD there are 128 frames remaining over 364
# bob.bio.spear@2020-01-03 13:09:38,854 -- INFO: After thresholded Energy-based VAD there are 100 frames remaining over 216
# bob.bio.spear@2020-01-03 13:09:38,906 -- INFO: After thresholded Energy-based VAD there are 107 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:38,961 -- INFO: After thresholded Energy-based VAD there are 61 frames remaining over 242
# bob.bio.spear@2020-01-03 13:09:38,997 -- INFO: After thresholded Energy-based VAD there are 209 frames remaining over 558
# bob.bio.spear@2020-01-03 13:09:39,105 -- INFO: After thresholded Energy-based VAD there are 219 frames remaining over 399
# bob.bio.spear@2020-01-03 13:09:39,214 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 489
# bob.bio.spear@2020-01-03 13:09:39,307 -- INFO: After thresholded Energy-based VAD there are 96 frames remaining over 207
# bob.bio.spear@2020-01-03 13:09:39,358 -- INFO: After thresholded Energy-based VAD there are 266 frames remaining over 432
# bob.bio.spear@2020-01-03 13:09:39,490 -- INFO: After thresholded Energy-based VAD there are 127 frames remaining over 355
# bob.bio.spear@2020-01-03 13:09:39,556 -- INFO: After thresholded Energy-based VAD there are 68 frames remaining over 302
# bob.bio.spear@2020-01-03 13:09:39,594 -- INFO: After thresholded Energy-based VAD there are 100 frames remaining over 239
# bob.bio.spear@2020-01-03 13:09:39,646 -- INFO: After thresholded Energy-based VAD there are 103 frames remaining over 268
# bob.bio.spear@2020-01-03 13:09:39,708 -- INFO: After thresholded Energy-based VAD there are 85 frames remaining over 211
# bob.bio.spear@2020-01-03 13:09:39,755 -- INFO: After thresholded Energy-based VAD there are 132 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:39,834 -- INFO: After thresholded Energy-based VAD there are 83 frames remaining over 220
# bob.bio.spear@2020-01-03 13:09:39,880 -- INFO: After thresholded Energy-based VAD there are 211 frames remaining over 339
# bob.bio.spear@2020-01-03 13:09:39,986 -- INFO: After thresholded Energy-based VAD there are 183 frames remaining over 485
# bob.bio.spear@2020-01-03 13:09:40,079 -- INFO: After thresholded Energy-based VAD there are 64 frames remaining over 177
# bob.bio.spear@2020-01-03 13:09:40,116 -- INFO: After thresholded Energy-based VAD there are 161 frames remaining over 447
# bob.bio.spear@2020-01-03 13:09:40,200 -- INFO: After thresholded Energy-based VAD there are 235 frames remaining over 501
# bob.bio.spear@2020-01-03 13:09:40,316 -- INFO: After thresholded Energy-based VAD there are 91 frames remaining over 231
# bob.bio.spear@2020-01-03 13:09:40,365 -- INFO: After thresholded Energy-based VAD there are 166 frames remaining over 506
# bob.bio.spear@2020-01-03 13:09:40,452 -- INFO: After thresholded Energy-based VAD there are 142 frames remaining over 451
# bob.bio.spear@2020-01-03 13:09:40,526 -- INFO: After thresholded Energy-based VAD there are 115 frames remaining over 208
# bob.bio.spear@2020-01-03 13:09:40,585 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 211
# bob.bio.spear@2020-01-03 13:09:40,628 -- INFO: After thresholded Energy-based VAD there are 222 frames remaining over 523
# bob.bio.spear@2020-01-03 13:09:40,740 -- INFO: After thresholded Energy-based VAD there are 141 frames remaining over 304
# bob.bio.spear@2020-01-03 13:09:40,812 -- INFO: After thresholded Energy-based VAD there are 137 frames remaining over 262
# bob.bio.spear@2020-01-03 13:09:40,881 -- INFO: After thresholded Energy-based VAD there are 89 frames remaining over 241
# bob.bio.spear@2020-01-03 13:09:40,928 -- INFO: After thresholded Energy-based VAD there are 113 frames remaining over 223
# bob.bio.spear@2020-01-03 13:09:40,987 -- INFO: After thresholded Energy-based VAD there are 256 frames remaining over 421
# bob.bio.spear@2020-01-03 13:09:41,116 -- INFO: After thresholded Energy-based VAD there are 167 frames remaining over 298
# bob.bio.spear@2020-01-03 13:09:41,199 -- INFO: After thresholded Energy-based VAD there are 49 frames remaining over 219
# bob.bio.spear@2020-01-03 13:09:41,228 -- INFO: After thresholded Energy-based VAD there are 83 frames remaining over 244
# bob.bio.spear@2020-01-03 13:09:41,274 -- INFO: After thresholded Energy-based VAD there are 302 frames remaining over 522
# bob.bio.spear@2020-01-03 13:09:41,422 -- INFO: After thresholded Energy-based VAD there are 133 frames remaining over 321
# bob.bio.spear@2020-01-03 13:09:41,491 -- INFO: After thresholded Energy-based VAD there are 149 frames remaining over 394
# bob.bio.spear@2020-01-03 13:09:41,568 -- INFO: After thresholded Energy-based VAD there are 158 frames remaining over 394
# bob.bio.spear@2020-01-03 13:09:41,649 -- INFO: After thresholded Energy-based VAD there are 97 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:41,700 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 185
# bob.bio.spear@2020-01-03 13:09:41,746 -- INFO: After thresholded Energy-based VAD there are 247 frames remaining over 410
# bob.bio.spear@2020-01-03 13:09:41,870 -- INFO: After thresholded Energy-based VAD there are 150 frames remaining over 434
# bob.bio.spear@2020-01-03 13:09:41,948 -- INFO: After thresholded Energy-based VAD there are 123 frames remaining over 253
# bob.bio.spear@2020-01-03 13:09:42,010 -- INFO: After thresholded Energy-based VAD there are 125 frames remaining over 262
# bob.bio.spear@2020-01-03 13:09:42,075 -- INFO: After thresholded Energy-based VAD there are 186 frames remaining over 446
# bob.bio.spear@2020-01-03 13:09:42,172 -- INFO: After thresholded Energy-based VAD there are 253 frames remaining over 489
# bob.bio.spear@2020-01-03 13:09:42,298 -- INFO: After thresholded Energy-based VAD there are 63 frames remaining over 285
# bob.bio.spear@2020-01-03 13:09:42,335 -- INFO: After thresholded Energy-based VAD there are 186 frames remaining over 377
# bob.bio.spear@2020-01-03 13:09:42,429 -- INFO: After thresholded Energy-based VAD there are 197 frames remaining over 352
# bob.bio.spear@2020-01-03 13:09:42,527 -- INFO: After thresholded Energy-based VAD there are 120 frames remaining over 217
# bob.bio.spear@2020-01-03 13:09:42,589 -- INFO: After thresholded Energy-based VAD there are 181 frames remaining over 334
# bob.bio.spear@2020-01-03 13:09:42,680 -- INFO: After thresholded Energy-based VAD there are 140 frames remaining over 394
# bob.bio.spear@2020-01-03 13:09:42,753 -- INFO: After thresholded Energy-based VAD there are 197 frames remaining over 347
# bob.bio.spear@2020-01-03 13:09:42,854 -- INFO: After thresholded Energy-based VAD there are 244 frames remaining over 519
# bob.bio.spear@2020-01-03 13:09:42,977 -- INFO: After thresholded Energy-based VAD there are 98 frames remaining over 340
# bob.bio.spear@2020-01-03 13:09:43,029 -- INFO: After thresholded Energy-based VAD there are 92 frames remaining over 249
# bob.bio.spear@2020-01-03 13:09:43,078 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 177
# bob.bio.spear@2020-01-03 13:09:43,113 -- INFO: After thresholded Energy-based VAD there are 163 frames remaining over 334
# bob.bio.spear@2020-01-03 13:09:43,195 -- INFO: After thresholded Energy-based VAD there are 61 frames remaining over 219
# bob.bio.spear@2020-01-03 13:09:43,229 -- INFO: After thresholded Energy-based VAD there are 57 frames remaining over 251
# bob.bio.spear@2020-01-03 13:09:43,262 -- INFO: After thresholded Energy-based VAD there are 102 frames remaining over 270
# bob.bio.spear@2020-01-03 13:09:43,315 -- INFO: After thresholded Energy-based VAD there are 152 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:43,392 -- INFO: After thresholded Energy-based VAD there are 119 frames remaining over 276
# bob.bio.spear@2020-01-03 13:09:43,454 -- INFO: After thresholded Energy-based VAD there are 309 frames remaining over 518
# bob.bio.spear@2020-01-03 13:09:43,606 -- INFO: After thresholded Energy-based VAD there are 100 frames remaining over 240
# bob.bio.spear@2020-01-03 13:09:43,658 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 186
# bob.bio.spear@2020-01-03 13:09:43,695 -- INFO: After thresholded Energy-based VAD there are 219 frames remaining over 369
# bob.bio.spear@2020-01-03 13:09:43,804 -- INFO: After thresholded Energy-based VAD there are 108 frames remaining over 226
# bob.bio.spear@2020-01-03 13:09:43,860 -- INFO: After thresholded Energy-based VAD there are 155 frames remaining over 377
# bob.bio.spear@2020-01-03 13:09:43,940 -- INFO: After thresholded Energy-based VAD there are 92 frames remaining over 266
# bob.bio.spear@2020-01-03 13:09:43,989 -- INFO: After thresholded Energy-based VAD there are 48 frames remaining over 215
# bob.bio.spear@2020-01-03 13:09:44,017 -- INFO: After thresholded Energy-based VAD there are 153 frames remaining over 275
# bob.bio.spear@2020-01-03 13:09:44,094 -- INFO: After thresholded Energy-based VAD there are 141 frames remaining over 253
# bob.bio.spear@2020-01-03 13:09:44,166 -- INFO: After thresholded Energy-based VAD there are 72 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:44,205 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 241
# bob.bio.spear@2020-01-03 13:09:44,262 -- INFO: After thresholded Energy-based VAD there are 105 frames remaining over 220
# bob.bio.spear@2020-01-03 13:09:44,317 -- INFO: After thresholded Energy-based VAD there are 131 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:44,384 -- INFO: After thresholded Energy-based VAD there are 49 frames remaining over 194
# bob.bio.spear@2020-01-03 13:09:44,413 -- INFO: After thresholded Energy-based VAD there are 121 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:44,475 -- INFO: After thresholded Energy-based VAD there are 104 frames remaining over 267
# bob.bio.spear@2020-01-03 13:09:44,530 -- INFO: After thresholded Energy-based VAD there are 244 frames remaining over 443
# bob.bio.spear@2020-01-03 13:09:44,652 -- INFO: After thresholded Energy-based VAD there are 196 frames remaining over 519
# bob.bio.spear@2020-01-03 13:09:44,754 -- INFO: After thresholded Energy-based VAD there are 275 frames remaining over 656
# bob.bio.spear@2020-01-03 13:09:44,891 -- INFO: After thresholded Energy-based VAD there are 69 frames remaining over 280
# bob.bio.spear@2020-01-03 13:09:44,929 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 185
# bob.bio.spear@2020-01-03 13:09:44,965 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:45,023 -- INFO: After thresholded Energy-based VAD there are 137 frames remaining over 225
# bob.bio.spear@2020-01-03 13:09:45,093 -- INFO: After thresholded Energy-based VAD there are 174 frames remaining over 428
# bob.bio.spear@2020-01-03 13:09:45,182 -- INFO: After thresholded Energy-based VAD there are 124 frames remaining over 239
# bob.bio.spear@2020-01-03 13:09:45,245 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 188
# bob.bio.spear@2020-01-03 13:09:45,281 -- INFO: After thresholded Energy-based VAD there are 92 frames remaining over 202
# bob.bio.spear@2020-01-03 13:09:45,329 -- INFO: After thresholded Energy-based VAD there are 80 frames remaining over 240
# bob.bio.spear@2020-01-03 13:09:45,373 -- INFO: After thresholded Energy-based VAD there are 246 frames remaining over 402
# bob.bio.spear@2020-01-03 13:09:45,494 -- INFO: After thresholded Energy-based VAD there are 147 frames remaining over 348
# bob.bio.spear@2020-01-03 13:09:45,571 -- INFO: After thresholded Energy-based VAD there are 190 frames remaining over 353
# bob.bio.spear@2020-01-03 13:09:45,666 -- INFO: After thresholded Energy-based VAD there are 145 frames remaining over 261
# bob.bio.spear@2020-01-03 13:09:45,739 -- INFO: After thresholded Energy-based VAD there are 120 frames remaining over 218
# bob.bio.spear@2020-01-03 13:09:45,801 -- INFO: After thresholded Energy-based VAD there are 134 frames remaining over 322
# bob.bio.spear@2020-01-03 13:09:45,870 -- INFO: After thresholded Energy-based VAD there are 99 frames remaining over 218
# bob.bio.spear@2020-01-03 13:09:45,923 -- INFO: After thresholded Energy-based VAD there are 128 frames remaining over 472
# bob.bio.spear@2020-01-03 13:09:45,991 -- INFO: After thresholded Energy-based VAD there are 106 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:46,047 -- INFO: After thresholded Energy-based VAD there are 198 frames remaining over 372
# bob.bio.spear@2020-01-03 13:09:46,147 -- INFO: After thresholded Energy-based VAD there are 113 frames remaining over 276
# bob.bio.spear@2020-01-03 13:09:46,205 -- INFO: After thresholded Energy-based VAD there are 89 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:46,252 -- INFO: After thresholded Energy-based VAD there are 158 frames remaining over 246
# bob.bio.spear@2020-01-03 13:09:46,332 -- INFO: After thresholded Energy-based VAD there are 115 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:46,393 -- INFO: After thresholded Energy-based VAD there are 226 frames remaining over 494
# bob.bio.spear@2020-01-03 13:09:46,506 -- INFO: After thresholded Energy-based VAD there are 146 frames remaining over 255
# bob.bio.spear@2020-01-03 13:09:46,581 -- INFO: After thresholded Energy-based VAD there are 283 frames remaining over 497
# bob.bio.spear@2020-01-03 13:09:46,723 -- INFO: After thresholded Energy-based VAD there are 211 frames remaining over 454
# bob.bio.spear@2020-01-03 13:09:46,830 -- INFO: After thresholded Energy-based VAD there are 127 frames remaining over 226
# bob.bio.spear@2020-01-03 13:09:46,895 -- INFO: After thresholded Energy-based VAD there are 125 frames remaining over 237
# bob.bio.spear@2020-01-03 13:09:46,959 -- INFO: After thresholded Energy-based VAD there are 209 frames remaining over 327
# bob.bio.spear@2020-01-03 13:09:47,063 -- INFO: After thresholded Energy-based VAD there are 150 frames remaining over 434
# bob.bio.spear@2020-01-03 13:09:47,141 -- INFO: After thresholded Energy-based VAD there are 77 frames remaining over 293
# bob.bio.spear@2020-01-03 13:09:47,184 -- INFO: After thresholded Energy-based VAD there are 128 frames remaining over 232
# bob.bio.spear@2020-01-03 13:09:47,249 -- INFO: After thresholded Energy-based VAD there are 172 frames remaining over 438
# bob.bio.spear@2020-01-03 13:09:47,338 -- INFO: After thresholded Energy-based VAD there are 206 frames remaining over 428
# bob.bio.spear@2020-01-03 13:09:47,443 -- INFO: After thresholded Energy-based VAD there are 131 frames remaining over 289
# bob.bio.spear@2020-01-03 13:09:47,509 -- INFO: After thresholded Energy-based VAD there are 73 frames remaining over 176
# bob.bio.spear@2020-01-03 13:09:47,548 -- INFO: After thresholded Energy-based VAD there are 105 frames remaining over 270
# bob.bio.spear@2020-01-03 13:09:47,605 -- INFO: After thresholded Energy-based VAD there are 289 frames remaining over 511
# bob.bio.spear@2020-01-03 13:09:47,747 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 223
# bob.bio.spear@2020-01-03 13:09:47,793 -- INFO: After thresholded Energy-based VAD there are 121 frames remaining over 257
# bob.bio.spear@2020-01-03 13:09:47,855 -- INFO: After thresholded Energy-based VAD there are 129 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:47,921 -- INFO: After thresholded Energy-based VAD there are 137 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:47,992 -- INFO: After thresholded Energy-based VAD there are 253 frames remaining over 519
# bob.bio.spear@2020-01-03 13:09:48,118 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 322
# bob.bio.spear@2020-01-03 13:09:48,175 -- INFO: After thresholded Energy-based VAD there are 67 frames remaining over 176
# bob.bio.spear@2020-01-03 13:09:48,212 -- INFO: After thresholded Energy-based VAD there are 94 frames remaining over 267
# bob.bio.spear@2020-01-03 13:09:48,263 -- INFO: After thresholded Energy-based VAD there are 273 frames remaining over 445
# bob.bio.spear@2020-01-03 13:09:48,399 -- INFO: After thresholded Energy-based VAD there are 244 frames remaining over 391
# bob.bio.spear@2020-01-03 13:09:48,520 -- INFO: After thresholded Energy-based VAD there are 165 frames remaining over 472
# bob.bio.spear@2020-01-03 13:09:48,606 -- INFO: After thresholded Energy-based VAD there are 159 frames remaining over 391
# bob.bio.spear@2020-01-03 13:09:48,689 -- INFO: After thresholded Energy-based VAD there are 292 frames remaining over 410
# bob.bio.spear@2020-01-03 13:09:48,831 -- INFO: After thresholded Energy-based VAD there are 164 frames remaining over 394
# bob.bio.spear@2020-01-03 13:09:48,916 -- INFO: After thresholded Energy-based VAD there are 126 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:48,980 -- INFO: After thresholded Energy-based VAD there are 179 frames remaining over 347
# bob.bio.spear@2020-01-03 13:09:49,070 -- INFO: After thresholded Energy-based VAD there are 64 frames remaining over 183
# bob.bio.spear@2020-01-03 13:09:49,105 -- INFO: After thresholded Energy-based VAD there are 126 frames remaining over 225
# bob.bio.spear@2020-01-03 13:09:49,169 -- INFO: After thresholded Energy-based VAD there are 124 frames remaining over 300
# bob.bio.spear@2020-01-03 13:09:49,233 -- INFO: After thresholded Energy-based VAD there are 78 frames remaining over 259
# bob.bio.spear@2020-01-03 13:09:49,276 -- INFO: After thresholded Energy-based VAD there are 198 frames remaining over 377
# bob.bio.spear@2020-01-03 13:09:49,376 -- INFO: After thresholded Energy-based VAD there are 109 frames remaining over 270
# bob.bio.spear@2020-01-03 13:09:49,433 -- INFO: After thresholded Energy-based VAD there are 96 frames remaining over 259
# bob.bio.spear@2020-01-03 13:09:49,485 -- INFO: After thresholded Energy-based VAD there are 194 frames remaining over 421
# bob.bio.spear@2020-01-03 13:09:49,583 -- INFO: After thresholded Energy-based VAD there are 285 frames remaining over 415
# bob.bio.spear@2020-01-03 13:09:49,723 -- INFO: After thresholded Energy-based VAD there are 219 frames remaining over 390
# bob.bio.spear@2020-01-03 13:09:49,833 -- INFO: After thresholded Energy-based VAD there are 196 frames remaining over 407
# bob.bio.spear@2020-01-03 13:09:49,931 -- INFO: After thresholded Energy-based VAD there are 51 frames remaining over 136
# bob.bio.spear@2020-01-03 13:09:49,960 -- INFO: After thresholded Energy-based VAD there are 175 frames remaining over 464
# bob.bio.spear@2020-01-03 13:09:50,052 -- INFO: After thresholded Energy-based VAD there are 211 frames remaining over 390
# bob.bio.spear@2020-01-03 13:09:50,158 -- INFO: After thresholded Energy-based VAD there are 297 frames remaining over 504
# bob.bio.spear@2020-01-03 13:09:50,305 -- INFO: After thresholded Energy-based VAD there are 90 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:50,354 -- INFO: After thresholded Energy-based VAD there are 212 frames remaining over 505
# bob.bio.spear@2020-01-03 13:09:50,461 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 210
# bob.bio.spear@2020-01-03 13:09:50,504 -- INFO: After thresholded Energy-based VAD there are 196 frames remaining over 338
# bob.bio.spear@2020-01-03 13:09:50,602 -- INFO: After thresholded Energy-based VAD there are 91 frames remaining over 241
# bob.bio.spear@2020-01-03 13:09:50,650 -- INFO: After thresholded Energy-based VAD there are 97 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:50,702 -- INFO: After thresholded Energy-based VAD there are 133 frames remaining over 272
# bob.bio.spear@2020-01-03 13:09:50,770 -- INFO: After thresholded Energy-based VAD there are 159 frames remaining over 310
# bob.bio.spear@2020-01-03 13:09:50,850 -- INFO: After thresholded Energy-based VAD there are 125 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:50,914 -- INFO: After thresholded Energy-based VAD there are 100 frames remaining over 240
# bob.bio.spear@2020-01-03 13:09:50,965 -- INFO: After thresholded Energy-based VAD there are 107 frames remaining over 203
# bob.bio.spear@2020-01-03 13:09:51,022 -- INFO: After thresholded Energy-based VAD there are 193 frames remaining over 553
# bob.bio.spear@2020-01-03 13:09:51,122 -- INFO: After thresholded Energy-based VAD there are 84 frames remaining over 175
# bob.bio.spear@2020-01-03 13:09:51,166 -- INFO: After thresholded Energy-based VAD there are 207 frames remaining over 367
# bob.bio.spear@2020-01-03 13:09:51,270 -- INFO: After thresholded Energy-based VAD there are 99 frames remaining over 215
# bob.bio.spear@2020-01-03 13:09:51,323 -- INFO: After thresholded Energy-based VAD there are 215 frames remaining over 374
# bob.bio.spear@2020-01-03 13:09:51,430 -- INFO: After thresholded Energy-based VAD there are 200 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:51,528 -- INFO: After thresholded Energy-based VAD there are 81 frames remaining over 194
# bob.bio.spear@2020-01-03 13:09:51,571 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 230
# bob.bio.spear@2020-01-03 13:09:51,628 -- INFO: After thresholded Energy-based VAD there are 181 frames remaining over 400
# bob.bio.spear@2020-01-03 13:09:51,720 -- INFO: After thresholded Energy-based VAD there are 97 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:51,770 -- INFO: After thresholded Energy-based VAD there are 67 frames remaining over 179
# bob.bio.spear@2020-01-03 13:09:51,808 -- INFO: After thresholded Energy-based VAD there are 180 frames remaining over 502
# bob.bio.spear@2020-01-03 13:09:51,902 -- INFO: After thresholded Energy-based VAD there are 214 frames remaining over 379
# bob.bio.spear@2020-01-03 13:09:52,009 -- INFO: After thresholded Energy-based VAD there are 137 frames remaining over 262
# bob.bio.spear@2020-01-03 13:09:52,079 -- INFO: After thresholded Energy-based VAD there are 136 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:52,149 -- INFO: After thresholded Energy-based VAD there are 257 frames remaining over 350
# bob.bio.spear@2020-01-03 13:09:52,274 -- INFO: After thresholded Energy-based VAD there are 92 frames remaining over 215
# bob.bio.spear@2020-01-03 13:09:52,322 -- INFO: After thresholded Energy-based VAD there are 178 frames remaining over 445
# bob.bio.spear@2020-01-03 13:09:52,413 -- INFO: After thresholded Energy-based VAD there are 132 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:52,480 -- INFO: After thresholded Energy-based VAD there are 139 frames remaining over 285
# bob.bio.spear@2020-01-03 13:09:52,552 -- INFO: After thresholded Energy-based VAD there are 191 frames remaining over 408
# bob.bio.spear@2020-01-03 13:09:52,649 -- INFO: After thresholded Energy-based VAD there are 107 frames remaining over 353
# bob.bio.spear@2020-01-03 13:09:52,708 -- INFO: After thresholded Energy-based VAD there are 272 frames remaining over 454
# bob.bio.spear@2020-01-03 13:09:52,842 -- INFO: After thresholded Energy-based VAD there are 290 frames remaining over 497
# bob.bio.spear@2020-01-03 13:09:52,986 -- INFO: After thresholded Energy-based VAD there are 167 frames remaining over 307
# bob.bio.spear@2020-01-03 13:09:53,070 -- INFO: After thresholded Energy-based VAD there are 71 frames remaining over 336
# bob.bio.spear@2020-01-03 13:09:53,111 -- INFO: After thresholded Energy-based VAD there are 288 frames remaining over 462
# bob.bio.spear@2020-01-03 13:09:53,252 -- INFO: After thresholded Energy-based VAD there are 183 frames remaining over 399
# bob.bio.spear@2020-01-03 13:09:53,345 -- INFO: After thresholded Energy-based VAD there are 288 frames remaining over 466
# bob.bio.spear@2020-01-03 13:09:53,487 -- INFO: After thresholded Energy-based VAD there are 116 frames remaining over 249
# bob.bio.spear@2020-01-03 13:09:53,547 -- INFO: After thresholded Energy-based VAD there are 139 frames remaining over 231
# bob.bio.spear@2020-01-03 13:09:53,617 -- INFO: After thresholded Energy-based VAD there are 114 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:53,675 -- INFO: After thresholded Energy-based VAD there are 134 frames remaining over 306
# bob.bio.spear@2020-01-03 13:09:53,743 -- INFO: After thresholded Energy-based VAD there are 168 frames remaining over 421
# bob.bio.spear@2020-01-03 13:09:53,830 -- INFO: After thresholded Energy-based VAD there are 235 frames remaining over 500
# bob.bio.spear@2020-01-03 13:09:53,948 -- INFO: After thresholded Energy-based VAD there are 51 frames remaining over 214
# bob.bio.spear@2020-01-03 13:09:53,977 -- INFO: After thresholded Energy-based VAD there are 126 frames remaining over 274
# bob.bio.spear@2020-01-03 13:09:54,042 -- INFO: After thresholded Energy-based VAD there are 63 frames remaining over 206
# bob.bio.spear@2020-01-03 13:09:54,078 -- INFO: After thresholded Energy-based VAD there are 224 frames remaining over 501
# bob.bio.spear@2020-01-03 13:09:54,192 -- INFO: After thresholded Energy-based VAD there are 232 frames remaining over 562
# bob.bio.spear@2020-01-03 13:09:54,308 -- INFO: After thresholded Energy-based VAD there are 123 frames remaining over 300
# bob.bio.spear@2020-01-03 13:09:54,374 -- INFO: After thresholded Energy-based VAD there are 239 frames remaining over 596
# bob.bio.spear@2020-01-03 13:09:54,493 -- INFO: After thresholded Energy-based VAD there are 82 frames remaining over 201
# bob.bio.spear@2020-01-03 13:09:54,538 -- INFO: After thresholded Energy-based VAD there are 157 frames remaining over 377
# bob.bio.spear@2020-01-03 13:09:54,620 -- INFO: After thresholded Energy-based VAD there are 229 frames remaining over 515
# bob.bio.spear@2020-01-03 13:09:54,736 -- INFO: After thresholded Energy-based VAD there are 89 frames remaining over 227
# bob.bio.spear@2020-01-03 13:09:54,784 -- INFO: After thresholded Energy-based VAD there are 229 frames remaining over 451
# bob.bio.spear@2020-01-03 13:09:54,898 -- INFO: After thresholded Energy-based VAD there are 138 frames remaining over 215
# bob.bio.spear@2020-01-03 13:09:54,968 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 515
# bob.bio.spear@2020-01-03 13:09:55,062 -- INFO: After thresholded Energy-based VAD there are 129 frames remaining over 253
# bob.bio.spear@2020-01-03 13:09:55,127 -- INFO: After thresholded Energy-based VAD there are 90 frames remaining over 192
# bob.bio.spear@2020-01-03 13:09:55,175 -- INFO: After thresholded Energy-based VAD there are 290 frames remaining over 403
# bob.bio.spear@2020-01-03 13:09:55,316 -- INFO: After thresholded Energy-based VAD there are 156 frames remaining over 250
# bob.bio.spear@2020-01-03 13:09:55,397 -- INFO: After thresholded Energy-based VAD there are 218 frames remaining over 592
# bob.bio.spear@2020-01-03 13:09:55,509 -- INFO: After thresholded Energy-based VAD there are 302 frames remaining over 505
# bob.bio.spear@2020-01-03 13:09:55,658 -- INFO: After thresholded Energy-based VAD there are 219 frames remaining over 481
# bob.bio.spear@2020-01-03 13:09:55,768 -- INFO: After thresholded Energy-based VAD there are 122 frames remaining over 241
# bob.bio.spear@2020-01-03 13:09:55,831 -- INFO: After thresholded Energy-based VAD there are 250 frames remaining over 433
# bob.bio.spear@2020-01-03 13:09:55,954 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 223
# bob.bio.spear@2020-01-03 13:09:56,000 -- INFO: After thresholded Energy-based VAD there are 207 frames remaining over 446
# bob.bio.spear@2020-01-03 13:09:56,105 -- INFO: After thresholded Energy-based VAD there are 129 frames remaining over 362
# bob.bio.spear@2020-01-03 13:09:56,172 -- INFO: After thresholded Energy-based VAD there are 68 frames remaining over 246
# bob.bio.spear@2020-01-03 13:09:56,209 -- INFO: After thresholded Energy-based VAD there are 52 frames remaining over 134
# bob.bio.spear@2020-01-03 13:09:56,240 -- INFO: After thresholded Energy-based VAD there are 271 frames remaining over 439
# bob.bio.spear@2020-01-03 13:09:56,374 -- INFO: After thresholded Energy-based VAD there are 116 frames remaining over 254
# bob.bio.spear@2020-01-03 13:09:56,434 -- INFO: After thresholded Energy-based VAD there are 138 frames remaining over 353
# bob.bio.spear@2020-01-03 13:09:56,505 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 445
# bob.bio.spear@2020-01-03 13:09:56,598 -- INFO: After thresholded Energy-based VAD there are 122 frames remaining over 270
# bob.bio.spear@2020-01-03 13:09:56,660 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 183
# bob.bio.spear@2020-01-03 13:09:56,702 -- INFO: After thresholded Energy-based VAD there are 165 frames remaining over 258
# bob.bio.spear@2020-01-03 13:09:56,785 -- INFO: After thresholded Energy-based VAD there are 71 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:56,824 -- INFO: After thresholded Energy-based VAD there are 171 frames remaining over 361
# bob.bio.spear@2020-01-03 13:09:56,911 -- INFO: After thresholded Energy-based VAD there are 84 frames remaining over 297
# bob.bio.spear@2020-01-03 13:09:56,956 -- INFO: After thresholded Energy-based VAD there are 82 frames remaining over 285
# bob.bio.spear@2020-01-03 13:09:57,000 -- INFO: After thresholded Energy-based VAD there are 78 frames remaining over 236
# bob.bio.spear@2020-01-03 13:09:57,043 -- INFO: After thresholded Energy-based VAD there are 151 frames remaining over 275
# bob.bio.spear@2020-01-03 13:09:57,119 -- INFO: After thresholded Energy-based VAD there are 127 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:57,186 -- INFO: After thresholded Energy-based VAD there are 227 frames remaining over 454
# bob.bio.spear@2020-01-03 13:09:57,299 -- INFO: After thresholded Energy-based VAD there are 145 frames remaining over 266
# bob.bio.spear@2020-01-03 13:09:57,372 -- INFO: After thresholded Energy-based VAD there are 110 frames remaining over 213
# bob.bio.spear@2020-01-03 13:09:57,429 -- INFO: After thresholded Energy-based VAD there are 121 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:57,491 -- INFO: After thresholded Energy-based VAD there are 148 frames remaining over 287
# bob.bio.spear@2020-01-03 13:09:57,566 -- INFO: After thresholded Energy-based VAD there are 180 frames remaining over 428
# bob.bio.spear@2020-01-03 13:09:57,657 -- INFO: After thresholded Energy-based VAD there are 145 frames remaining over 235
# bob.bio.spear@2020-01-03 13:09:57,729 -- INFO: After thresholded Energy-based VAD there are 89 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:57,777 -- INFO: After thresholded Energy-based VAD there are 202 frames remaining over 424
# bob.bio.spear@2020-01-03 13:09:57,880 -- INFO: After thresholded Energy-based VAD there are 157 frames remaining over 348
# bob.bio.spear@2020-01-03 13:09:57,959 -- INFO: After thresholded Energy-based VAD there are 159 frames remaining over 288
# bob.bio.spear@2020-01-03 13:09:58,041 -- INFO: After thresholded Energy-based VAD there are 190 frames remaining over 351
# bob.bio.spear@2020-01-03 13:09:58,137 -- INFO: After thresholded Energy-based VAD there are 127 frames remaining over 360
# bob.bio.spear@2020-01-03 13:09:58,204 -- INFO: After thresholded Energy-based VAD there are 229 frames remaining over 445
# bob.bio.spear@2020-01-03 13:09:58,319 -- INFO: After thresholded Energy-based VAD there are 208 frames remaining over 352
# bob.bio.spear@2020-01-03 13:09:58,424 -- INFO: After thresholded Energy-based VAD there are 263 frames remaining over 566
# bob.bio.spear@2020-01-03 13:09:58,557 -- INFO: After thresholded Energy-based VAD there are 129 frames remaining over 347
# bob.bio.spear@2020-01-03 13:09:58,624 -- INFO: After thresholded Energy-based VAD there are 159 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:58,703 -- INFO: After thresholded Energy-based VAD there are 67 frames remaining over 228
# bob.bio.spear@2020-01-03 13:09:58,741 -- INFO: After thresholded Energy-based VAD there are 244 frames remaining over 385
# bob.bio.spear@2020-01-03 13:09:58,862 -- INFO: After thresholded Energy-based VAD there are 76 frames remaining over 249
# bob.bio.spear@2020-01-03 13:09:58,903 -- INFO: After thresholded Energy-based VAD there are 167 frames remaining over 334
# bob.bio.spear@2020-01-03 13:09:58,987 -- INFO: After thresholded Energy-based VAD there are 121 frames remaining over 213
# bob.bio.spear@2020-01-03 13:09:59,049 -- INFO: After thresholded Energy-based VAD there are 122 frames remaining over 226
# bob.bio.spear@2020-01-03 13:09:59,110 -- INFO: After thresholded Energy-based VAD there are 77 frames remaining over 306
# bob.bio.spear@2020-01-03 13:09:59,153 -- INFO: After thresholded Energy-based VAD there are 103 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:59,206 -- INFO: After thresholded Energy-based VAD there are 94 frames remaining over 245
# bob.bio.spear@2020-01-03 13:09:59,256 -- INFO: After thresholded Energy-based VAD there are 118 frames remaining over 212
# bob.bio.spear@2020-01-03 13:09:59,316 -- INFO: After thresholded Energy-based VAD there are 112 frames remaining over 241
# bob.bio.spear@2020-01-03 13:09:59,374 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 242
# bob.bio.spear@2020-01-03 13:09:59,420 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 167
# bob.bio.spear@2020-01-03 13:09:59,465 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 296
# bob.bio.spear@2020-01-03 13:09:59,555 -- INFO: After thresholded Energy-based VAD there are 138 frames remaining over 262
# ...
# bob.bio.spear@2020-01-03 13:11:01,457 -- INFO: After thresholded Energy-based VAD there are 222 frames remaining over 387
# bob.bio.spear@2020-01-03 13:11:01,567 -- INFO: After thresholded Energy-based VAD there are 73 frames remaining over 157
# bob.bio.spear@2020-01-03 13:11:01,607 -- INFO: After thresholded Energy-based VAD there are 207 frames remaining over 492
# bob.bio.spear@2020-01-03 13:11:01,714 -- INFO: After thresholded Energy-based VAD there are 193 frames remaining over 487
# bob.bio.spear@2020-01-03 13:11:01,814 -- INFO: After thresholded Energy-based VAD there are 234 frames remaining over 424
# bob.bio.spear@2020-01-03 13:11:01,933 -- INFO: After thresholded Energy-based VAD there are 203 frames remaining over 338
# bob.bio.spear@2020-01-03 13:11:02,035 -- INFO: After thresholded Energy-based VAD there are 57 frames remaining over 195
# bob.bio.spear@2020-01-03 13:11:02,068 -- INFO: After thresholded Energy-based VAD there are 155 frames remaining over 352
# bob.bio.spear@2020-01-03 13:11:02,147 -- INFO: After thresholded Energy-based VAD there are 150 frames remaining over 258
# bob.bio.spear@2020-01-03 13:11:02,223 -- INFO: After thresholded Energy-based VAD there are 48 frames remaining over 144
# bob.bio.spear@2020-01-03 13:11:02,251 -- INFO: After thresholded Energy-based VAD there are 79 frames remaining over 219
# bob.bio.spear@2020-01-03 13:11:02,293 -- INFO: After thresholded Energy-based VAD there are 112 frames remaining over 207
# bob.bio.spear@2020-01-03 13:11:02,351 -- INFO: After thresholded Energy-based VAD there are 87 frames remaining over 152
# bob.bio.spear@2020-01-03 13:11:02,398 -- INFO: After thresholded Energy-based VAD there are 203 frames remaining over 411
# bob.bio.spear@2020-01-03 13:11:02,500 -- INFO: After thresholded Energy-based VAD there are 75 frames remaining over 204
# bob.bio.spear@2020-01-03 13:11:02,542 -- INFO: After thresholded Energy-based VAD there are 220 frames remaining over 379
# bob.bio.spear@2020-01-03 13:11:02,651 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 300
# bob.bio.spear@2020-01-03 13:11:02,709 -- INFO: After thresholded Energy-based VAD there are 82 frames remaining over 243
# bob.bio.spear@2020-01-03 13:11:02,754 -- INFO: After thresholded Energy-based VAD there are 112 frames remaining over 254
# bob.bio.spear@2020-01-03 13:11:02,811 -- INFO: After thresholded Energy-based VAD there are 92 frames remaining over 188
# bob.bio.spear@2020-01-03 13:11:02,861 -- INFO: After thresholded Energy-based VAD there are 353 frames remaining over 620
# bob.bio.spear@2020-01-03 13:11:03,040 -- INFO: After thresholded Energy-based VAD there are 212 frames remaining over 352
# bob.bio.spear@2020-01-03 13:11:03,145 -- INFO: After thresholded Energy-based VAD there are 44 frames remaining over 178
# bob.bio.spear@2020-01-03 13:11:03,171 -- INFO: After thresholded Energy-based VAD there are 74 frames remaining over 244
# bob.bio.spear@2020-01-03 13:11:03,212 -- INFO: After thresholded Energy-based VAD there are 101 frames remaining over 309
# bob.bio.spear@2020-01-03 13:11:03,267 -- INFO: After thresholded Energy-based VAD there are 256 frames remaining over 445
# bob.bio.spear@2020-01-03 13:11:03,394 -- INFO: After thresholded Energy-based VAD there are 60 frames remaining over 186
# bob.bio.spear@2020-01-03 13:11:03,428 -- INFO: After thresholded Energy-based VAD there are 174 frames remaining over 484
# bob.bio.spear@2020-01-03 13:11:03,519 -- INFO: After thresholded Energy-based VAD there are 49 frames remaining over 219
# bob.bio.spear@2020-01-03 13:11:03,548 -- INFO: After thresholded Energy-based VAD there are 121 frames remaining over 300
# bob.bio.spear@2020-01-03 13:11:03,611 -- INFO: After thresholded Energy-based VAD there are 93 frames remaining over 211
# bob.bio.spear@2020-01-03 13:11:03,660 -- INFO: After thresholded Energy-based VAD there are 136 frames remaining over 242
# bob.bio.spear@2020-01-03 13:11:03,729 -- INFO: After thresholded Energy-based VAD there are 69 frames remaining over 185
# bob.bio.spear@2020-01-03 13:11:03,766 -- INFO: After thresholded Energy-based VAD there are 74 frames remaining over 204
# bob.bio.spear@2020-01-03 13:11:03,806 -- INFO: After thresholded Energy-based VAD there are 83 frames remaining over 195
# bob.bio.spear@2020-01-03 13:11:03,851 -- INFO: After thresholded Energy-based VAD there are 142 frames remaining over 471
# bob.bio.spear@2020-01-03 13:11:03,926 -- INFO: After thresholded Energy-based VAD there are 157 frames remaining over 276
# bob.bio.spear@2020-01-03 13:11:04,007 -- INFO: After thresholded Energy-based VAD there are 190 frames remaining over 445
# bob.bio.spear@2020-01-03 13:11:04,104 -- INFO: After thresholded Energy-based VAD there are 82 frames remaining over 279
# bob.bio.spear@2020-01-03 13:11:04,149 -- INFO: After thresholded Energy-based VAD there are 146 frames remaining over 365
# bob.bio.spear@2020-01-03 13:11:04,225 -- INFO: After thresholded Energy-based VAD there are 228 frames remaining over 369
# bob.bio.spear@2020-01-03 13:11:04,339 -- INFO: After thresholded Energy-based VAD there are 148 frames remaining over 514
# bob.bio.spear@2020-01-03 13:11:04,417 -- INFO: After thresholded Energy-based VAD there are 146 frames remaining over 309
# bob.bio.spear@2020-01-03 13:11:04,492 -- INFO: After thresholded Energy-based VAD there are 132 frames remaining over 305
# bob.bio.spear@2020-01-03 13:11:04,561 -- INFO: After thresholded Energy-based VAD there are 213 frames remaining over 356
# bob.bio.spear@2020-01-03 13:11:04,668 -- INFO: After thresholded Energy-based VAD there are 186 frames remaining over 547
# bob.bio.spear@2020-01-03 13:11:04,763 -- INFO: After thresholded Energy-based VAD there are 96 frames remaining over 238
# bob.bio.spear@2020-01-03 13:11:04,815 -- INFO: After thresholded Energy-based VAD there are 136 frames remaining over 420
# bob.bio.spear@2020-01-03 13:11:04,887 -- INFO: After thresholded Energy-based VAD there are 201 frames remaining over 334
# bob.bio.spear@2020-01-03 13:11:04,989 -- INFO: After thresholded Energy-based VAD there are 135 frames remaining over 297
# bob.bio.spear@2020-01-03 13:11:05,057 -- INFO: After thresholded Energy-based VAD there are 171 frames remaining over 291
# bob.bio.spear@2020-01-03 13:11:05,143 -- INFO: After thresholded Energy-based VAD there are 109 frames remaining over 274
# bob.bio.spear@2020-01-03 13:11:05,199 -- INFO: After thresholded Energy-based VAD there are 168 frames remaining over 343
# bob.bio.spear@2020-01-03 13:11:05,284 -- INFO: After thresholded Energy-based VAD there are 158 frames remaining over 445
# bob.bio.spear@2020-01-03 13:11:05,366 -- INFO: After thresholded Energy-based VAD there are 128 frames remaining over 217
# bob.bio.spear@2020-01-03 13:11:05,431 -- INFO: After thresholded Energy-based VAD there are 205 frames remaining over 309
# bob.bio.spear@2020-01-03 13:11:05,532 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 178
# bob.bio.spear@2020-01-03 13:11:05,577 -- INFO: After thresholded Energy-based VAD there are 109 frames remaining over 208
# bob.bio.spear@2020-01-03 13:11:05,633 -- INFO: After thresholded Energy-based VAD there are 75 frames remaining over 148
# bob.bio.spear@2020-01-03 13:11:05,672 -- INFO: After thresholded Energy-based VAD there are 172 frames remaining over 352
# bob.bio.spear@2020-01-03 13:11:05,758 -- INFO: After thresholded Energy-based VAD there are 153 frames remaining over 272
# bob.bio.spear@2020-01-03 13:11:05,835 -- INFO: After thresholded Energy-based VAD there are 198 frames remaining over 344
# bob.bio.spear@2020-01-03 13:11:05,933 -- INFO: After thresholded Energy-based VAD there are 73 frames remaining over 157
# bob.bio.spear@2020-01-03 13:11:05,972 -- INFO: After thresholded Energy-based VAD there are 127 frames remaining over 238
# bob.bio.spear@2020-01-03 13:11:06,036 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 195
# bob.bio.spear@2020-01-03 13:11:06,081 -- INFO: After thresholded Energy-based VAD there are 123 frames remaining over 288
# bob.bio.spear@2020-01-03 13:11:06,144 -- INFO: After thresholded Energy-based VAD there are 104 frames remaining over 181
# bob.bio.spear@2020-01-03 13:11:06,197 -- INFO: After thresholded Energy-based VAD there are 136 frames remaining over 251
# bob.bio.spear@2020-01-03 13:11:06,265 -- INFO: After thresholded Energy-based VAD there are 128 frames remaining over 229
# bob.bio.spear@2020-01-03 13:11:06,330 -- INFO: After thresholded Energy-based VAD there are 64 frames remaining over 165
# bob.bio.spear@2020-01-03 13:11:06,365 -- INFO: After thresholded Energy-based VAD there are 179 frames remaining over 323
# bob.bio.spear@2020-01-03 13:11:06,454 -- INFO: After thresholded Energy-based VAD there are 108 frames remaining over 206
# bob.bio.spear@2020-01-03 13:11:06,510 -- INFO: After thresholded Energy-based VAD there are 138 frames remaining over 347
# bob.bio.spear@2020-01-03 13:11:06,582 -- INFO: After thresholded Energy-based VAD there are 161 frames remaining over 267
# bob.bio.spear@2020-01-03 13:11:06,662 -- INFO: After thresholded Energy-based VAD there are 131 frames remaining over 218
# bob.bio.spear@2020-01-03 13:11:06,727 -- INFO: After thresholded Energy-based VAD there are 131 frames remaining over 254
# bob.bio.spear@2020-01-03 13:11:06,793 -- INFO: After thresholded Energy-based VAD there are 98 frames remaining over 352
# bob.bio.spear@2020-01-03 13:11:06,845 -- INFO: After thresholded Energy-based VAD there are 108 frames remaining over 259
# bob.bio.spear@2020-01-03 13:11:06,902 -- INFO: After thresholded Energy-based VAD there are 185 frames remaining over 416
# bob.bio.spear@2020-01-03 13:11:06,997 -- INFO: After thresholded Energy-based VAD there are 286 frames remaining over 471
# bob.bio.spear@2020-01-03 13:11:07,139 -- INFO: After thresholded Energy-based VAD there are 250 frames remaining over 564
# bob.bio.spear@2020-01-03 13:11:07,264 -- INFO: After thresholded Energy-based VAD there are 156 frames remaining over 420
# bob.bio.spear@2020-01-03 13:11:07,344 -- INFO: After thresholded Energy-based VAD there are 116 frames remaining over 300
# bob.bio.spear@2020-01-03 13:11:07,405 -- INFO: After thresholded Energy-based VAD there are 184 frames remaining over 467
# bob.bio.spear@2020-01-03 13:11:07,498 -- INFO: After thresholded Energy-based VAD there are 119 frames remaining over 262
# bob.bio.spear@2020-01-03 13:11:07,559 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 199
# bob.bio.spear@2020-01-03 13:11:07,595 -- INFO: After thresholded Energy-based VAD there are 106 frames remaining over 309
# bob.bio.spear@2020-01-03 13:11:07,650 -- INFO: After thresholded Energy-based VAD there are 99 frames remaining over 188
# bob.bio.spear@2020-01-03 13:11:07,701 -- INFO: After thresholded Energy-based VAD there are 152 frames remaining over 261
# bob.bio.spear@2020-01-03 13:11:07,777 -- INFO: After thresholded Energy-based VAD there are 115 frames remaining over 244
# bob.bio.spear@2020-01-03 13:11:07,838 -- INFO: After thresholded Energy-based VAD there are 278 frames remaining over 488
# bob.bio.spear@2020-01-03 13:11:07,976 -- INFO: After thresholded Energy-based VAD there are 193 frames remaining over 306
# bob.bio.spear@2020-01-03 13:11:08,072 -- INFO: After thresholded Energy-based VAD there are 273 frames remaining over 569
# bob.bio.spear@2020-01-03 13:11:08,208 -- INFO: After thresholded Energy-based VAD there are 94 frames remaining over 228
# bob.bio.spear@2020-01-03 13:11:08,257 -- INFO: After thresholded Energy-based VAD there are 140 frames remaining over 263
# bob.bio.spear@2020-01-03 13:11:08,328 -- INFO: After thresholded Energy-based VAD there are 201 frames remaining over 311
# bob.bio.spear@2020-01-03 13:11:08,429 -- INFO: After thresholded Energy-based VAD there are 116 frames remaining over 471
# bob.bio.spear@2020-01-03 13:11:08,493 -- INFO: After thresholded Energy-based VAD there are 278 frames remaining over 413
# bob.bio.spear@2020-01-03 13:11:08,631 -- INFO: After thresholded Energy-based VAD there are 166 frames remaining over 285
# bob.bio.spear@2020-01-03 13:11:08,715 -- INFO: After thresholded Energy-based VAD there are 80 frames remaining over 304
# bob.bio.spear@2020-01-03 13:11:08,759 -- INFO: After thresholded Energy-based VAD there are 131 frames remaining over 234
# bob.bio.spear@2020-01-03 13:11:08,826 -- INFO: After thresholded Energy-based VAD there are 211 frames remaining over 590
# bob.bio.spear@2020-01-03 13:11:08,934 -- INFO: After thresholded Energy-based VAD there are 180 frames remaining over 441
# bob.bio.spear@2020-01-03 13:11:09,026 -- INFO: After thresholded Energy-based VAD there are 73 frames remaining over 390
# bob.bio.spear@2020-01-03 13:11:09,068 -- INFO: After thresholded Energy-based VAD there are 153 frames remaining over 360
# bob.bio.spear@2020-01-03 13:11:09,147 -- INFO: After thresholded Energy-based VAD there are 243 frames remaining over 445
# bob.bio.spear@2020-01-03 13:11:09,269 -- INFO: After thresholded Energy-based VAD there are 231 frames remaining over 346
# bob.bio.spear@2020-01-03 13:11:09,385 -- INFO: After thresholded Energy-based VAD there are 141 frames remaining over 432
# bob.bio.spear@2020-01-03 13:11:09,459 -- INFO: After thresholded Energy-based VAD there are 93 frames remaining over 221
# bob.bio.spear@2020-01-03 13:11:09,508 -- INFO: After thresholded Energy-based VAD there are 128 frames remaining over 289
# bob.bio.spear@2020-01-03 13:11:09,573 -- INFO: After thresholded Energy-based VAD there are 77 frames remaining over 241
# bob.bio.spear@2020-01-03 13:11:09,615 -- INFO: After thresholded Energy-based VAD there are 78 frames remaining over 187
# bob.bio.spear@2020-01-03 13:11:09,657 -- INFO: After thresholded Energy-based VAD there are 86 frames remaining over 309
# bob.bio.spear@2020-01-03 13:11:09,703 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 362
# bob.bio.spear@2020-01-03 13:11:09,797 -- INFO: After thresholded Energy-based VAD there are 322 frames remaining over 518
# bob.bio.spear@2020-01-03 13:11:09,954 -- INFO: After thresholded Energy-based VAD there are 160 frames remaining over 257
# bob.bio.spear@2020-01-03 13:11:10,033 -- INFO: After thresholded Energy-based VAD there are 65 frames remaining over 228
# bob.bio.spear@2020-01-03 13:11:10,070 -- INFO: After thresholded Energy-based VAD there are 245 frames remaining over 436
# bob.bio.spear@2020-01-03 13:11:10,190 -- INFO: After thresholded Energy-based VAD there are 108 frames remaining over 184
# bob.bio.spear@2020-01-03 13:11:10,246 -- INFO: After thresholded Energy-based VAD there are 240 frames remaining over 441
# bob.bio.spear@2020-01-03 13:11:10,369 -- INFO: After thresholded Energy-based VAD there are 132 frames remaining over 261
# bob.bio.spear@2020-01-03 13:11:10,435 -- INFO: After thresholded Energy-based VAD there are 48 frames remaining over 131
# bob.bio.spear@2020-01-03 13:11:10,462 -- INFO: After thresholded Energy-based VAD there are 87 frames remaining over 203
# bob.bio.spear@2020-01-03 13:11:10,509 -- INFO: After thresholded Energy-based VAD there are 209 frames remaining over 424
# bob.bio.spear@2020-01-03 13:11:10,613 -- INFO: After thresholded Energy-based VAD there are 71 frames remaining over 182
# bob.bio.spear@2020-01-03 13:11:10,653 -- INFO: After thresholded Energy-based VAD there are 145 frames remaining over 416
# bob.bio.spear@2020-01-03 13:11:10,726 -- INFO: After thresholded Energy-based VAD there are 107 frames remaining over 232
# bob.bio.spear@2020-01-03 13:11:10,782 -- INFO: After thresholded Energy-based VAD there are 185 frames remaining over 336
# bob.bio.spear@2020-01-03 13:11:10,873 -- INFO: After thresholded Energy-based VAD there are 78 frames remaining over 283
# 1310 files processed in 1.693708749999996 minutes.
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:49: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
print(Xf[y==0].shape)
# Out:
# (1010,)

# %% [markdown]
# ### Saving features

# %%
np.save('X1.npy',Xf)
np.save('y1.npy',y)
print('Feature and label matrices saved to disk')
# Out:
# Feature and label matrices saved to disk

# %% [markdown]
# ### Loading features

# %%
# Load already extracter features to skip the preprocessing-extraction stage
# Xf = np.load('train_features_10.npy')
# y = np.load('y_10.npy')
Xf = np.load('X.npy',allow_pickle=True)
y = np.load('y.npy',allow_pickle=True)

# %%
print(Xf.shape)
# Out:
# (655,)

# %% [markdown]
# # GMM - ML Classification

# %% [markdown]
# ## GMM Training
# Train the GMMs for natural and synthetic speach. For documentation on bob.bio k-means and GMM machines see:
# https://pythonhosted.org/bob.learn.em/guide.html
#
# You can also skip the training stage and load an already trained GMM model (see cell **Loading GMM Model**).

# %%
# Parameters of the GMM machines
n_gaussians = 128 # number of Gaussians
max_iterats = 25 # maximum number of iterations

# %% [markdown]
# ### GMM for natural speech

# %%
# Initialize and train k-means machine: the means will initialize EM algorithm for GMM machine
start_time = time.clock()
kmeans_nat = em.KMeansMachine(n_gaussians,n_ceps)
kmeansTrainer = em.KMeansTrainer()
print(kmeans_nat.shape,Xf[y==1].shape)
em.train(kmeansTrainer, kmeans_nat, np.vstack(Xf[y==1]), max_iterations = max_iterats, convergence_threshold = 1e-5)
#kmeans_nat.means

# initialize and train GMM machine
gmm_nat = em.GMMMachine(n_gaussians,n_ceps)
trainer = em.ML_GMMTrainer(True, True, True)
gmm_nat.means = kmeans_nat.means
em.train(trainer, gmm_nat, np.vstack(Xf[y==1]), max_iterations = max_iterats, convergence_threshold = 1e-5)
#gmm_nat.save(HDF5File('gmm_nat.hdf5', 'w'))
print("Done in:", (time.clock() - start_time)/60, "minutes")
print(gmm_nat)
# Out:
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# (128, 60) (300,)
# Done in: 0.7205086166666661 minutes
# <bob.learn.em.GMMMachine object at 0x7f9649115af0>
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### GMM for synthetic speech

# %%
# initialize and train k-means machine: the means will initialize EM algorithm for GMM machine
start_time = time.clock()
kmeans_synt = em.KMeansMachine(n_gaussians,n_ceps)
kmeansTrainer = em.KMeansTrainer()
print(kmeans_synt.shape,Xf[y==0].shape)
em.train(kmeansTrainer, kmeans_synt, np.vstack(Xf[y==0]), max_iterations = max_iterats, convergence_threshold = 1e-5)

# initialize and train GMM machine
gmm_synt = em.GMMMachine(n_gaussians,n_ceps)
trainer = em.ML_GMMTrainer(True, True, True)
gmm_synt.means = kmeans_synt.means
em.train(trainer, gmm_synt, np.vstack(Xf[y==0]), max_iterations = max_iterats, convergence_threshold = 1e-5)
print("Done in:", (time.clock() - start_time)/60, "minutes")
#gmm_synt.save(HDF5File('gmm_synt.hdf5', 'w'))
print(gmm_synt)
# Out:
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# (128, 60) (1010,)
# Done in: 2.4534923833333324 minutes
# <bob.learn.em.GMMMachine object at 0x7f9649c09470>
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   del sys.path[0]

# %% [markdown]
# ### Loading GMM model

# %%
gmm_nat = em.GMMMachine()
gmm_nat.load(HDF5File('gmm_nat.hdf5', 'r'))
gmm_synt = em.GMMMachine()
gmm_synt.load(HDF5File('gmm_synt.hdf5','r'))

# %%
np.save('p_gmm_ml_eval_10.npy',llr_score)
np.save('z_gmm_ml_eval_est_10.npy',z_gmm)

# %% [markdown]
# ## GMM-ML Scoring
# Extract the features for the testing data, compute the likelihood ratio test and  compute ROC AUC and estimated EER scores.

# %%
status = 'evalu' # 'devel'(= test) OR 'evalu'(= hold out)
start_time = time.clock()

if status == 'devel':
    subfolders = devel_subfls
    ground_truth = devel
elif status == 'evalu':
    subfolders = evalu_subfls
    ground_truth = evalu
n_subfls = len(subfolders)
# initialize score and class arrays
llr_gmm_score = np.zeros(len(ground_truth),)
z_gmm = np.zeros(len(ground_truth),)
print(status)

vad = preprocessor.Energy_Thr(ratio_threshold=.1)
cepstrum = extractor.Cepstral()

k = 0
thr = .5
speaker_list = ground_truth.folder.unique()

for speaker_id in speaker_list:
    #speaker = ground_truth[ground_truth.folder==speaker_id]
    f_list = list(ground_truth[ground_truth.folder==speaker_id].file)
    folder = "".join([WAV_FOLDER,speaker_id,'/'])
    print(f_list)
    print(speaker_id, end=',')

    for f in f_list:
        f_name = "".join([folder,f,'.wav'])
        if os.path.exists(f_name):
            x = read(f_name)
            # voice activity detection
            vad_data = vad(x)
            if vad_data:
                if not vad_data[2].max():
                    vad = preprocessor.Energy_Thr(ratio_threshold=.08)
                    vad_data = vad(x)
                    vad = preprocessor.Energy_Thr(ratio_threshold=.1)
                # MFCC extraction 
                mfcc = cepstrum(vad_data)
                # Log likelihood ratio computation
                llr_gmm_score[k] = gmm_nat(mfcc)-gmm_synt(mfcc)
                z_gmm[k] = int(llr_gmm_score[k]>0)
                k += 1
        
ground_truth['z'] = ground_truth.source.map(lambda x: int(x=='human'))
ground_truth['z_gmm'] = z_gmm
ground_truth['score_gmm'] = llr_gmm_score
#print(roc_auc_score(ground_truth.z, ground_truth.z_gmm))
print(k,"files processed in",(time.clock()-start_time)/60,"minutes.")
# Out:
# evalu
# ['ELJ10001', 'ELJ10002', 'ELJ10003', 'ELJ10004', 'ELJ10005', 'ELJ10006', 'ELJ10007', 'ELJ10008', 'ELJ10009', 'ELJ10010', 'ELJ10011', 'ELJ10012', 'ELJ10013', 'ELJ10014', 'ELJ10015', 'ELJ10016', 'ELJ10017', 'ELJ10018', 'ELJ10019', 'ELJ10020']
# ELJ1,bob.bio.spear@2020-01-03 14:17:37,622 -- INFO: After thresholded Energy-based VAD there are 239 frames remaining over 338
# bob.bio.spear@2020-01-03 14:17:37,749 -- INFO: After thresholded Energy-based VAD there are 168 frames remaining over 255
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# bob.bio.spear@2020-01-03 14:17:37,840 -- INFO: After thresholded Energy-based VAD there are 284 frames remaining over 302
# bob.bio.spear@2020-01-03 14:17:37,988 -- INFO: After thresholded Energy-based VAD there are 222 frames remaining over 283
# bob.bio.spear@2020-01-03 14:17:38,105 -- INFO: After thresholded Energy-based VAD there are 115 frames remaining over 234
# bob.bio.spear@2020-01-03 14:17:38,168 -- INFO: After thresholded Energy-based VAD there are 171 frames remaining over 260
# bob.bio.spear@2020-01-03 14:17:38,260 -- INFO: After thresholded Energy-based VAD there are 167 frames remaining over 275
# bob.bio.spear@2020-01-03 14:17:38,350 -- INFO: After thresholded Energy-based VAD there are 183 frames remaining over 255
# bob.bio.spear@2020-01-03 14:17:38,447 -- INFO: After thresholded Energy-based VAD there are 197 frames remaining over 296
# bob.bio.spear@2020-01-03 14:17:38,552 -- INFO: After thresholded Energy-based VAD there are 194 frames remaining over 265
# bob.bio.spear@2020-01-03 14:17:38,654 -- INFO: After thresholded Energy-based VAD there are 176 frames remaining over 278
# bob.bio.spear@2020-01-03 14:17:38,750 -- INFO: After thresholded Energy-based VAD there are 141 frames remaining over 268
# bob.bio.spear@2020-01-03 14:17:38,827 -- INFO: After thresholded Energy-based VAD there are 111 frames remaining over 231
# bob.bio.spear@2020-01-03 14:17:38,889 -- INFO: After thresholded Energy-based VAD there are 182 frames remaining over 236
# bob.bio.spear@2020-01-03 14:17:38,986 -- INFO: After thresholded Energy-based VAD there are 218 frames remaining over 262
# bob.bio.spear@2020-01-03 14:17:39,101 -- INFO: After thresholded Energy-based VAD there are 175 frames remaining over 296
# bob.bio.spear@2020-01-03 14:17:39,196 -- INFO: After thresholded Energy-based VAD there are 158 frames remaining over 275
# bob.bio.spear@2020-01-03 14:17:39,282 -- INFO: After thresholded Energy-based VAD there are 201 frames remaining over 296
# bob.bio.spear@2020-01-03 14:17:39,390 -- INFO: After thresholded Energy-based VAD there are 201 frames remaining over 291
# bob.bio.spear@2020-01-03 14:17:39,496 -- INFO: After thresholded Energy-based VAD there are 157 frames remaining over 247
# 20 files processed in 0.03302966666666786 minutes.
# /home/sundata/anaconda3/envs/bob_py3/lib/python3.7/site-packages/ipykernel_launcher.py:52: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
# Performance evaluation

#实际humans个数
humans = sum(ground_truth.z==1)
print("实际humans个数:", humans)

#实际spoofed个数
spoofed = sum(ground_truth.z==0)
print("实际spoofed个数:", spoofed)

#预测humans个数
pre_humans = sum(ground_truth.z_gmm==1)
print("预测humans个数:", pre_humans)

#预测spoofed个数
pre_spoofed = sum(ground_truth.z_gmm==0)
print("预测spoofed个数:", pre_spoofed)

tp = 0
tn = 0
fp = 0
fn = 0
for i in ground_truth.index:
    if ground_truth.z[i] == 1 and ground_truth.z_gmm[i]==1:
        tp = tp + 1
    elif ground_truth.z[i] == 1 and ground_truth.z_gmm[i]==0:
        fn = fn + 1
    elif ground_truth.z[i] == 0 and ground_truth.z_gmm[i]==0:
        tn = tn + 1
    elif ground_truth.z[i] == 0 and ground_truth.z_gmm[i]==1:
        fp = fp + 1
print("TP_Num:", tp)
print("TN_Num:", tn)
print("FP_Num:", fp)
print("FN_Num:", fn)

tpr = tp/(tp+fn)
fpr = fp/(fp+tn)
tnr = tn/(fp+tn)
fnr = fn/(tp+fn)
acc = (tp+tn)/(tp+fp+tn+fn)
print("TPR:", tpr)
print("FPR:", fpr)
print("TNR:", tnr)
print("FNR:", fnr)
print("Accuracy:", acc)

# humans = z_gmm[z_dvl==0]
# spoofed = z_gmm[z_dvl==1]
# fnr = 100*(1-(humans<thr).sum()/len(humans))
# fpr = 100*(1-(spoofed>=thr).sum()/len(spoofed))
# print("ROC AUC score:", roc_auc_score(z_dvl,z_gmm))
# print("False negative rate %:", fnr)
# print("False positive rate %:", fpr)
# print("EER %: <=", (fnr+fpr)/2)
# Out:
# 实际humans个数: 0
# 实际spoofed个数: 20
# 预测humans个数: 11
# 预测spoofed个数: 9
# TP_Num: 0
# TN_Num: 9
# FP_Num: 11
# FN_Num: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-85-6d35d5a2b2c8> in <module>
#      35 print("FN_Num:", fn)
#      36
# ---> 37 tpr = tp/(tp+fn)
#      38 fpr = fp/(fp+tn)
#      39 tnr = tn/(fp+tn)
#
# ZeroDivisionError: division by zero

# %%
ground_truth
# Out:
#      folder        file method source  z  z_gmm  score_gmm
# 2597     D1  D1_1002598  human  human  1    1.0   1.447147
# 2598     D1  D1_1002599  human  human  1    1.0   2.336380
# 2599     D1  D1_1002600  human  human  1    1.0   3.082637
# 2600     D1  D1_1002601  human  human  1    1.0   3.716948
# 2601     D1  D1_1002602  human  human  1    1.0   0.914256
# ...     ...         ...    ...    ... ..    ...        ...
# 7767     D3  D3_1007768     S1  spoof  0    0.0  -2.641017
# 7768     D3  D3_1007769     S2  spoof  0    0.0  -0.571958
# 7769     D3  D3_1007770     S3  spoof  0    0.0  -5.441518
# 7770     D3  D3_1007771     S4  spoof  0    0.0  -4.762759
# 7771     D3  D3_1007772     S5  spoof  0    0.0  -1.451432
#
# [3050 rows x 7 columns]

# %% [markdown]
# ### EER computation
#
# Adjust the threshold $thr$ to reduce $FNR-FPR$ for a more accurate estimate of the $EER$.
#
# The Equal Error Rate ($EER$) is the value where the false negative rate ($FNR$) equals the false positive rate ($FPR$). It's an error metric commonly used to characterize biometric systems.

# %%
thr = -.115
pz = llr_gmm_score
spoofed = pz[np.array(ground_truth.z)==1]
humans = pz[np.array(ground_truth.z)==0]
fnr = 100*(humans>thr).sum()/len(humans)
fpr = 100*(spoofed<=thr).sum()/len(spoofed)
print("False negative vs positive rates %:", fnr, fpr)
print("FNR - FPR %:", fnr-fpr)
if np.abs(fnr-fpr) <.25:
    print("EER =", (fnr+fpr)/2,"%")
else:
    print("EER ~", (fnr+fpr)/2,"%")
# Out:
# False negative vs positive rates %: 4.701754385964913 10.0
# FNR - FPR %: -5.298245614035087
# EER ~ 7.350877192982456 %
